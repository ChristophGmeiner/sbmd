# %% [markdown]
# # First Analysis for Munich Traffic DWH
#
# ## Connect

# %%
import configparser
# %load_ext sql

# %%
config = configparser.ConfigParser()
config.read("dwh.cfg")
# Out:
# ['dwh.cfg']

# %%
connstring = config['Red']['DWH_CS']

# %%
# %sql connstring
# Out:
# 'Connected: dwhuser@sbmd1'

# %% [markdown]
# ## Data Size
# Please find below some SQL queries, which show the size for each table in the data model

# %%
# %sql SELECT COUNT(*) FROM t01_delay_fact;
# Out:
#  * postgresql://dwhuser:***@redshift-cluster-1sbmd.cg1lpo6kzhm9.eu-central-1.redshift.amazonaws.com:5439/sbmd1
# 1 rows affected.
# [(314014,)]

# %%
# %sql SELECT COUNT(*) FROM t02_dim_time;
# Out:
#  * postgresql://dwhuser:***@redshift-cluster-1sbmd.cg1lpo6kzhm9.eu-central-1.redshift.amazonaws.com:5439/sbmd1
# 1 rows affected.
# [(1143,)]

# %%
# %sql SELECT COUNT(*) FROM t03_dim_conn;
# Out:
#  * postgresql://dwhuser:***@redshift-cluster-1sbmd.cg1lpo6kzhm9.eu-central-1.redshift.amazonaws.com:5439/sbmd1
# 1 rows affected.
# [(22797,)]

# %%
# %sql SELECT COUNT(*) FROM t04_dim_part;
# Out:
#  * postgresql://dwhuser:***@redshift-cluster-1sbmd.cg1lpo6kzhm9.eu-central-1.redshift.amazonaws.com:5439/sbmd1
# 1 rows affected.
# [(2,)]

# %%
# %sql SELECT COUNT(*) FROM t05_dim_weather;
# Out:
#  * postgresql://dwhuser:***@redshift-cluster-1sbmd.cg1lpo6kzhm9.eu-central-1.redshift.amazonaws.com:5439/sbmd1
# 1 rows affected.
# [(81267,)]

# %% [markdown]
# ## Examples for basic questions
#
# #### What is the average delay in % per transport method?

# %%
# %%sql
# SELECT
# part_id,
# AVG(delay_sec) / AVG(duration_sec) AS Avg_Delay_Perc
# FROM
# t01_delay_fact
# GROUP BY
# part_id
# Out:
#  * postgresql://dwhuser:***@redshift-cluster-1sbmd.cg1lpo6kzhm9.eu-central-1.redshift.amazonaws.com:5439/sbmd1
# 2 rows affected.
# [(1, -0.00529920074190287), (2, -0.0209391236504283)]

# %% [markdown]
# #### What is the average delay in % per weekday and hour?

# %%
# %%sql
# SELECT
# t.weekday,
# t.hour,
# AVG(delay_sec) / AVG(duration_sec) AS Avg_Delay_Perc
# FROM
# t01_delay_fact f
# LEFT JOIN t02_dim_time t
# ON t.time_id = f.time_id
# GROUP BY
# t.weekday,
# t.hour
# ORDER BY 1, 2
# Out:
#  * postgresql://dwhuser:***@redshift-cluster-1sbmd.cg1lpo6kzhm9.eu-central-1.redshift.amazonaws.com:5439/sbmd1
# 168 rows affected.
# [(0, 0, 0.00127409105600769),
#  (0, 1, 0.00710956952703219),
#  (0, 2, 0.0292850375135891),
#  (0, 3, -0.307713467048711),
#  (0, 4, 0.0173170762302588),
#  (0, 5, 0.00190579480759325),
#  (0, 6, -0.00212368130514054),
#  (0, 7, 0.00176590783677071),
#  (0, 8, 0.000504720932858425),
#  (0, 9, 0.00063719133201412),
#  (0, 10, -0.00280266754845848),
#  (0, 11, -0.00486858321606195),
#  (0, 12, -0.00206664501249961),
#  (0, 13, -0.00202988213201926),
#  (0, 14, -0.000162417646935601),
#  (0, 15, 0.000862046982316907),
#  (4, 7, -0.0103080916606567),
#  (4, 8, -0.00842490584162389),
#  (4, 9, -0.012320795150272),
#  (4, 10, -0.00588065752702085),
#  (4, 11, -0.00528316328251605),
#  (4, 12, -0.00525129678779707),
#  (4, 13, -0.0131897008523938),
#  (4, 14, -0.008371951501691),
#  (4, 15, -0.0110104694546039),
#  (4, 16, -0.0132255448883098),
#  (4, 17, -0.0153115197518888),
#  (4, 18, -0.0114818198509732),
#  (4, 19, -0.0106870305716309),
#  (4, 20, -0.00847036105096846),
#  (4, 21, 0.478499317482229),
#  (4, 22, 0.265892076965863),
#  (4, 23, -2.57881225397912),
#  (5, 0, -0.0110417906417113),
#  (5, 1, -0.0152059866016456),
#  (5, 2, 0.00912925769690865),
#  (5, 3, -0.00154075369806313),
#  (5, 4, -0.00246198899917245),
#  (5, 5, -0.00382218987860785),
#  (5, 6, -0.00759501042103049),
#  (5, 7, -0.0146427901866574),
#  (5, 8, -0.01115251250135),
#  (5, 9, -0.00589638449060923),
#  (5, 10, -0.00553517910504882),
#  (5, 11, -0.00554964881633822),
#  (5, 12, -0.00679055682043958),
#  (5, 13, -0.0101718200893767),
#  (5, 14, -0.0104940531412195),
#  (5, 15, -0.0117356163153694),
#  (5, 16, -0.0130624132043001),
#  (5, 17, -0.0174282302426515),
#  (5, 18, -0.0129335074800564),
#  (5, 19, -0.0154754544249246),
#  (5, 20, -0.0108550469628715),
#  (5, 21, -0.008937751206225),
#  (5, 22, 0.614515256981458),
#  (5, 23, -4.27093403193999),
#  (6, 0, -0.00157468624639573),
#  (6, 1, 0.00376268573681809),
#  (6, 2, 0.00454240433763953),
#  (6, 3, 0.0774529516027828),
#  (6, 4, 0.00849065148343245),
#  (6, 5, -0.00133813468088551),
#  (6, 6, -0.00186612137641984),
#  (6, 7, -0.0027138776039618),
#  (6, 8, -0.00218842672570019),
#  (6, 9, -0.00557874551298062),
#  (6, 10, -0.00748918157329818),
#  (6, 11, -0.0077669236506323),
#  (6, 12, -0.00999014968134064),
#  (6, 13, -0.00581642354183542),
#  (6, 14, -0.00331785322311376),
#  (6, 15, -0.00634018775097782),
#  (6, 16, -0.00264777297639486),
#  (6, 17, -0.0040304183104643),
#  (6, 18, -0.00366372635533794),
#  (6, 19, -0.00267795996547699),
#  (6, 20, -0.00263879894099568),
#  (6, 21, -0.00602701118712351),
#  (6, 22, 0.0144473910706205),
#  (6, 23, -0.656895678837416)]

# %% [markdown]
# #### What is the average delay per weather state?

# %%
# %%sql
# SELECT
# w.weather_status,
# AVG(delay_sec) / AVG(duration_sec) AS Avg_Delay_Perc
# FROM
# t01_delay_fact f
# LEFT JOIN t05_dim_weather w
# ON w.w_id = f.w_id
# GROUP BY
# w.weather_status
# Out:
#  * postgresql://dwhuser:***@redshift-cluster-1sbmd.cg1lpo6kzhm9.eu-central-1.redshift.amazonaws.com:5439/sbmd1
# 10 rows affected.
# [(None, -0.00663731804815434),
#  ('Squall', -0.00129894989594874),
#  ('Clouds', -0.0060385500720267),
#  ('Clear', 0.00188537089673403),
#  ('Drizzle', -0.0068433648202205),
#  ('Snow', -0.00955287029696606),
#  ('Rain', -0.00755250303502734),
#  ('Mist', -0.00348252582048926),
#  ('Fog', -0.00121224675812693),
#  ('Thunderstorm', -0.0185595275756617)]
